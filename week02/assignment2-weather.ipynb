# %%
# Importing Libraries
import matplotlib.pyplot as plt
import pandas
from datetime import datetime

# %%
# Read in the csv using Pandas
weather_df = pandas.read_csv("weatherreadings1.csv")
weather_df #view the csv
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...

# %%
#View a list of the column names:
weather_df.columns
# Out:
# Index(['siteId', 'reportStartDateTime', 'reportEndDateTime', 'collectionName',
#        'isPublic', 'isLatestVersion', 'observationType', 'softwareType',
#        'windDirection', 'relativeHumidity', 'windSpeed_MilePerHour',
#        'windSpeed_MetrePerSecond', 'dryBulbTemperature_Fahrenheit',
#        'dryBulbTemperature_Celsius', 'wetBulbTemperature_Fahrenheit',
#        'wetBulbTemperature_Celsius', 'rainfallAmount_Inch',
#        'rainfallAmount_Millimetre', 'rainfallRate_InchPerHour',
#        'rainfallRate_MillimetrePerHour', 'airPressure_InchOfMercury',
#        'airPressure_Hectopascal', 'dewPointTemperature_Fahrenheit',
#        'dewPointTemperature_Celsius', 'isOfficial', 'isDcnn', 'longitude',
#        'latitude', 'height', 'id', 'localReportEndDateTime', 'externalSiteId',
#        'createdDateTime', 'version', 'externalId'],
#       dtype='object')

# %%
#Extract the time and dry bulb temperature columns
weather_df[["dryBulbTemperature_Celsius", "reportEndDateTime"]] #The timedata is stored as a string in the format '%Y-%m-%dT%H:%M:%S%z'
# Out:
#     dryBulbTemperature_Celsius          reportEndDateTime
# 0                    15.944444  2024-10-02T16:15:00+00:00
# 1                    15.777778  2024-10-02T16:45:00+00:00
# 2                    15.111111  2024-10-02T17:00:00+00:00
# 3                    14.277778  2024-10-02T17:15:00+00:00
# 4                    13.666667  2024-10-02T17:30:00+00:00
# ..                         ...                        ...
# 84                   14.611111  2024-10-03T14:00:00+00:00
# 85                   14.944444  2024-10-03T14:15:00+00:00
# 86                   14.944444  2024-10-03T14:30:00+00:00
# 87                   14.944444  2024-10-03T14:45:00+00:00
# 88                   14.722222  2024-10-03T15:00:00+00:00
#
# [89 rows x 2 columns]

# %%
# Convert the time data to a format that can be used ofr the plot. 
time_of_measurement = []
for date in weather_df["reportEndDateTime"]:
    date = datetime.strptime(date, '%Y-%m-%dT%H:%M:%S%z') 
    time_of_measurement.append(date.strftime("%H:%M"))
print(time_of_measurement)
# Out:
# ['16:15', '16:45', '17:00', '17:15', '17:30', '17:45', '18:00', '18:15', '18:30', '18:45', '19:00', '19:15', '19:30', '19:45', '20:00', '20:15', '20:30', '20:45', '21:00', '21:15', '21:30', '21:45', '22:00', '22:15', '22:30', '22:45', '23:00', '23:15', '23:30', '23:45', '00:00', '00:15', '00:30', '00:45', '01:00', '01:15', '01:30', '01:45', '02:00', '02:15', '02:45', '03:00', '03:15', '03:30', '03:45', '04:00', '04:15', '04:30', '04:45', '05:00', '05:15', '05:30', '05:45', '06:00', '06:15', '06:30', '06:45', '07:00', '07:15', '07:30', '07:45', '08:00', '08:15', '08:30', '08:45', '09:00', '09:30', '09:45', '10:00', '10:15', '10:30', '10:45', '11:00', '11:15', '11:30', '11:45', '12:00', '12:15', '12:30', '12:45', '13:00', '13:15', '13:30', '13:45', '14:00', '14:15', '14:30', '14:45', '15:00']

# %%
fig, ax = plt.subplots()
ax.scatter(
    time_of_measurement,
    weather_df["dryBulbTemperature_Celsius"],
    label="Drybulb Temperature", color="blue"

)
ax.scatter(
    time_of_measurement,
    weather_df["wetBulbTemperature_Celsius"],
    label="Wetbulb Temperature", color="red"
)
ax.set_xticks(ticks = time_of_measurement[::4])
ax.set_xticklabels(time_of_measurement[::4], rotation=45, 
                   fontdict= {'fontsize': 'x-small',}
                   )
ax.set_xlabel(f"Time of Measurement \n(Measurements taken between 02nd and 03rd October, 2024)")
ax.set_ylabel("Drybulb Temperature (°C)")
ax.set_title("Temperature vs. Time 2nd - 3rd Oct, 2024",
             fontdict = {'fontsize': 'large','fontweight' : "bold",}
             )
ax.legend()

# %% [markdown]
# *********
# ## END
